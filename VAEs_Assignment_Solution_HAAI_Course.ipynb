# %%
import numpy as np
import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import Input, Model
from tensorflow.keras.layers import Layer, Conv2D, Flatten, Dense, Reshape, Conv2DTranspose
import matplotlib.pyplot as plt

# %%
#Sampling layer
class Sampling(Layer):

	def call(self, inputs):
		z_mean, z_log_var = inputs
		batch = tf.shape(z_mean)[0]
		dim = tf.shape(z_mean)[1]
		epsilon = tf.keras.backend.random_normal(shape =(batch, dim))
		return z_mean + tf.exp(0.5 * z_log_var) * epsilon

# %%
# Define Encoder Model
latent_dim = 2

encoder_inputs = Input(shape =(28, 28, 1))
x = Conv2D(32, 3, activation ="relu", strides = 2, padding ="same")(encoder_inputs)
x = Conv2D(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Flatten()(x)
x = Dense(16, activation ="relu")(x)
z_mean = Dense(latent_dim, name ="z_mean")(x)
z_log_var = Dense(latent_dim, name ="z_log_var")(x)
z = Sampling()([z_mean, z_log_var])
encoder = Model(encoder_inputs, [z_mean, z_log_var, z], name ="encoder")
encoder.summary()
# Out:
# Model: "encoder"
# __________________________________________________________________________________________________
#  Layer (type)                Output Shape                 Param #   Connected to
# ==================================================================================================
#  input_1 (InputLayer)        [(None, 28, 28, 1)]          0         []
#
#  conv2d (Conv2D)             (None, 14, 14, 32)           320       ['input_1[0][0]']
#
#  conv2d_1 (Conv2D)           (None, 7, 7, 64)             18496     ['conv2d[0][0]']
#
#  flatten (Flatten)           (None, 3136)                 0         ['conv2d_1[0][0]']
#
#  dense (Dense)               (None, 16)                   50192     ['flatten[0][0]']
#
#  z_mean (Dense)              (None, 2)                    34        ['dense[0][0]']
#
#  z_log_var (Dense)           (None, 2)                    34        ['dense[0][0]']
#
#  sampling (Sampling)         (None, 2)                    0         ['z_mean[0][0]',
#                                                                      'z_log_var[0][0]']
#
# ==================================================================================================
# Total params: 69076 (269.83 KB)
# Trainable params: 69076 (269.83 KB)
# Non-trainable params: 0 (0.00 Byte)
# __________________________________________________________________________________________________

# %%
# Define Decoder Architecture
latent_inputs = keras.Input(shape =(latent_dim, ))
x = Dense(7 * 7 * 64, activation ="relu")(latent_inputs)
x = Reshape((7, 7, 64))(x)
x = Conv2DTranspose(64, 3, activation ="relu", strides = 2, padding ="same")(x)
x = Conv2DTranspose(32, 3, activation ="relu", strides = 2, padding ="same")(x)
decoder_outputs = Conv2DTranspose(1, 3, activation ="sigmoid", padding ="same")(x)
decoder = Model(latent_inputs, decoder_outputs, name ="decoder")
decoder.summary()
# Out:
# Model: "decoder"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_2 (InputLayer)        [(None, 2)]               0
#
#  dense_1 (Dense)             (None, 3136)              9408
#
#  reshape (Reshape)           (None, 7, 7, 64)          0
#
#  conv2d_transpose (Conv2DTr  (None, 14, 14, 64)        36928
#  anspose)
#
#  conv2d_transpose_1 (Conv2D  (None, 28, 28, 32)        18464
#  Transpose)
#
#  conv2d_transpose_2 (Conv2D  (None, 28, 28, 1)         289
#  Transpose)
#
# =================================================================
# Total params: 65089 (254.25 KB)
# Trainable params: 65089 (254.25 KB)
# Non-trainable params: 0 (0.00 Byte)
# _________________________________________________________________

# %%
#Define the complete variational autoencoder architecture
class VAE(keras.Model):
	def __init__(self, encoder, decoder, **kwargs):
		super(VAE, self).__init__(**kwargs)
		self.encoder = encoder
		self.decoder = decoder

	def train_step(self, data):
		if isinstance(data, tuple):
			data = data[0]
		with tf.GradientTape() as tape:
			z_mean, z_log_var, z = encoder(data)
			reconstruction = decoder(z)
			reconstruction_loss = tf.reduce_mean(
				keras.losses.binary_crossentropy(data, reconstruction)
			)
			reconstruction_loss *= 28 * 28
			kl_loss = 1 + z_log_var - tf.square(z_mean) - tf.exp(z_log_var)
			kl_loss = tf.reduce_mean(kl_loss)
			kl_loss *= -0.5
			total_loss = reconstruction_loss + kl_loss
		grads = tape.gradient(total_loss, self.trainable_weights)
		self.optimizer.apply_gradients(zip(grads, self.trainable_weights))
		return {
			"loss": total_loss,
			"reconstruction_loss": reconstruction_loss,
			"kl_loss": kl_loss,
		}

# %%
#Load the fashion mnist dataset
(x_train, _), (x_test, _) = keras.datasets.fashion_mnist.load_data()
fmnist_images = np.concatenate([x_train, x_test], axis = 0)
#Expansion of dimension for adding a color map dimension
fmnist_images = np.expand_dims(fmnist_images, -1).astype("float32") / 255

#Compile and train the VAE model
vae = VAE(encoder, decoder)
vae.compile(optimizer ='rmsprop')
vae.fit(fmnist_images, epochs = 50, batch_size = 64)
# Out:
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-labels-idx1-ubyte.gz
# 29515/29515 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/train-images-idx3-ubyte.gz
# 26421880/26421880 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-labels-idx1-ubyte.gz
# 5148/5148 [==============================] - 0s 0us/step
# Downloading data from https://storage.googleapis.com/tensorflow/tf-keras-datasets/t10k-images-idx3-ubyte.gz
# 4422102/4422102 [==============================] - 0s 0us/step
# Epoch 1/50
# 1094/1094 [==============================] - 20s 8ms/step - loss: 296.5086 - reconstruction_loss: 292.4129 - kl_loss: 4.0957
# Epoch 2/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 272.7029 - reconstruction_loss: 269.2136 - kl_loss: 3.4893
# Epoch 3/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 267.8939 - reconstruction_loss: 264.4720 - kl_loss: 3.4219
# Epoch 4/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 265.1248 - reconstruction_loss: 261.7004 - kl_loss: 3.4244
# Epoch 5/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 263.2883 - reconstruction_loss: 259.8168 - kl_loss: 3.4715
# Epoch 6/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 261.8711 - reconstruction_loss: 258.3696 - kl_loss: 3.5015
# Epoch 7/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 260.7383 - reconstruction_loss: 257.2041 - kl_loss: 3.5341
# Epoch 8/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 259.9437 - reconstruction_loss: 256.3862 - kl_loss: 3.5575
# Epoch 9/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 259.2776 - reconstruction_loss: 255.6822 - kl_loss: 3.5954
# Epoch 10/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 258.5936 - reconstruction_loss: 254.9865 - kl_loss: 3.6071
# Epoch 11/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 258.1883 - reconstruction_loss: 254.5551 - kl_loss: 3.6332
# Epoch 12/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 257.7555 - reconstruction_loss: 254.1021 - kl_loss: 3.6533
# Epoch 13/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 257.3679 - reconstruction_loss: 253.7006 - kl_loss: 3.6673
# Epoch 14/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 257.0645 - reconstruction_loss: 253.3829 - kl_loss: 3.6816
# Epoch 15/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 256.8038 - reconstruction_loss: 253.1114 - kl_loss: 3.6924
# Epoch 16/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 256.3915 - reconstruction_loss: 252.6787 - kl_loss: 3.7128
# Epoch 17/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 256.1296 - reconstruction_loss: 252.4063 - kl_loss: 3.7233
# Epoch 18/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 255.8788 - reconstruction_loss: 252.1483 - kl_loss: 3.7305
# Epoch 19/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.9077 - reconstruction_loss: 252.1597 - kl_loss: 3.7480
# Epoch 20/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.5843 - reconstruction_loss: 251.8267 - kl_loss: 3.7576
# Epoch 21/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.4468 - reconstruction_loss: 251.6722 - kl_loss: 3.7747
# Epoch 22/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 255.2545 - reconstruction_loss: 251.4691 - kl_loss: 3.7854
# Epoch 23/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.0394 - reconstruction_loss: 251.2552 - kl_loss: 3.7841
# Epoch 24/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.9937 - reconstruction_loss: 251.2006 - kl_loss: 3.7931
# Epoch 25/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 255.1357 - reconstruction_loss: 251.3275 - kl_loss: 3.8082
# Epoch 26/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 254.8856 - reconstruction_loss: 251.0713 - kl_loss: 3.8143
# Epoch 27/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.7213 - reconstruction_loss: 250.9012 - kl_loss: 3.8201
# Epoch 28/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.7601 - reconstruction_loss: 250.9396 - kl_loss: 3.8205
# Epoch 29/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 254.6222 - reconstruction_loss: 250.7927 - kl_loss: 3.8295
# Epoch 30/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.5331 - reconstruction_loss: 250.7123 - kl_loss: 3.8208
# Epoch 31/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 254.3624 - reconstruction_loss: 250.5346 - kl_loss: 3.8279
# Epoch 32/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.3924 - reconstruction_loss: 250.5419 - kl_loss: 3.8506
# Epoch 33/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.2107 - reconstruction_loss: 250.3659 - kl_loss: 3.8448
# Epoch 34/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.0958 - reconstruction_loss: 250.2341 - kl_loss: 3.8617
# Epoch 35/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 254.1297 - reconstruction_loss: 250.2783 - kl_loss: 3.8514
# Epoch 36/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.1731 - reconstruction_loss: 250.3130 - kl_loss: 3.8601
# Epoch 37/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.9173 - reconstruction_loss: 250.0546 - kl_loss: 3.8627
# Epoch 38/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.8955 - reconstruction_loss: 250.0337 - kl_loss: 3.8618
# Epoch 39/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.0791 - reconstruction_loss: 250.2009 - kl_loss: 3.8782
# Epoch 40/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.9557 - reconstruction_loss: 250.0838 - kl_loss: 3.8720
# Epoch 41/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.8248 - reconstruction_loss: 249.9491 - kl_loss: 3.8756
# Epoch 42/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.8469 - reconstruction_loss: 249.9562 - kl_loss: 3.8907
# Epoch 43/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 254.0312 - reconstruction_loss: 250.1547 - kl_loss: 3.8765
# Epoch 44/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.8811 - reconstruction_loss: 250.0002 - kl_loss: 3.8810
# Epoch 45/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.8720 - reconstruction_loss: 249.9830 - kl_loss: 3.8891
# Epoch 46/50
# 1094/1094 [==============================] - 7s 6ms/step - loss: 253.9046 - reconstruction_loss: 250.0285 - kl_loss: 3.8760
# Epoch 47/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.7737 - reconstruction_loss: 249.8873 - kl_loss: 3.8863
# Epoch 48/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.7581 - reconstruction_loss: 249.8641 - kl_loss: 3.8940
# Epoch 49/50
# 1094/1094 [==============================] - 8s 7ms/step - loss: 253.7042 - reconstruction_loss: 249.7989 - kl_loss: 3.9052
# Epoch 50/50
# 1094/1094 [==============================] - 7s 7ms/step - loss: 253.9931 - reconstruction_loss: 250.0952 - kl_loss: 3.8979

# %%
def plot_latent(encoder, decoder):
	n = 9
	img_dim = 28
	scale = 2.0
	figsize = 15
	figure = np.zeros((img_dim * n, img_dim * n))

	grid_x = np.linspace(-scale, scale, n)
	grid_y = np.linspace(-scale, scale, n)[::-1]

	for i, yi in enumerate(grid_y):
		for j, xi in enumerate(grid_x):
			z_sample = np.array([[xi, yi]])
			x_decoded = decoder.predict(z_sample)
			images = x_decoded[0].reshape(img_dim, img_dim)
			figure[
				i * img_dim : (i + 1) * img_dim,
				j * img_dim : (j + 1) * img_dim,
			] = images

	plt.figure(figsize =(figsize, figsize))
	start_range = img_dim // 2
	end_range = n * img_dim + start_range + 1
	pixel_range = np.arange(start_range, end_range, img_dim)
	sample_range_x = np.round(grid_x, 1)
	sample_range_y = np.round(grid_y, 1)
	#plt.xticks(pixel_range, sample_range_x)
	#plt.yticks(pixel_range, sample_range_y)
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.imshow(figure, cmap ="Greys_r")
	plt.show()


plot_latent(encoder, decoder)
# Out:
# 1/1 [==============================] - 0s 333ms/step
# 1/1 [==============================] - 0s 36ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 22ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 19ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 18ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 20ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 21ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 16ms/step
# 1/1 [==============================] - 0s 17ms/step
# 1/1 [==============================] - 0s 16ms/step

# %%
def plot_label_clusters(encoder, decoder, data, test_lab):
	z_mean, _, _ = encoder.predict(data)
	plt.figure(figsize =(12, 10))
	sc = plt.scatter(z_mean[:, 0], z_mean[:, 1], c = test_lab)
	cbar = plt.colorbar(sc, ticks = range(10))
	cbar.ax.set_yticklabels([labels.get(i) for i in range(10)])
	plt.xlabel("z[0]")
	plt.ylabel("z[1]")
	plt.show()


labels = {0 :"T-shirt / top",
1: "Trouser",
2: "Pullover",
3: "Dress",
4: "Coat",
5: "Sandal",
6: "Shirt",
7: "Sneaker",
8: "Bag",
9: "Ankle boot"}

(x_train, y_train), _ = keras.datasets.fashion_mnist.load_data()
x_train = np.expand_dims(x_train, -1).astype("float32") / 255
plot_label_clusters(encoder, decoder, x_train, y_train)
# Out:
# 1875/1875 [==============================] - 4s 2ms/step
